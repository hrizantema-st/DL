# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5242, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
print('Sample data', words[:10])
print(dictionary[words[]])
# Out:
# Sample data ['the', 'of', 'and', 'one', 'in', 'a', 'to', 'zero', 'nine', 'two']
# 2

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'originated', 'anarchism', 'term', 'as', 'originated', 'term', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# WARNING:tensorflow:From /home/hstancheva/DL/assignment1/.env/lib/python3.5/site-packages/tensorflow/python/ops/nn_impl.py:1344: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.004990
# Nearest to time: quod, cultivation, softball, maclaurin, repudiation, toxicology, adamic, grunt,
# Nearest to eight: speer, lincolnshire, call, artillery, biqa, yerushalayim, burnham, talked,
# Nearest to has: dev, imf, peacekeeping, carbonates, anabaptists, ephedrine, eldr, tgs,
# Nearest to from: revolutionized, interceptors, finger, commits, khoisan, alegre, searchlight, tea,
# Nearest to into: pc, psr, excepted, serial, slap, compiles, toga, transportation,
# Nearest to states: spherical, gua, prosecution, moonshine, erne, foibles, langevin, cheques,
# Nearest to nine: stewardship, endurance, texas, let, nineteen, jogaila, ulaanbaatar, brotherhood,
# Nearest to d: dakota, supports, hall, nullified, pseudoscience, elijah, macrobiotics, mahindra,
# Nearest to been: superposition, unlicensed, securing, abatis, pike, refutable, archaea, cherry,
# Nearest to people: hides, coltrane, gerda, knocks, porky, faculty, northwards, dependent,
# Nearest to about: abnormally, matched, proving, stiles, scrip, zines, morality, nucleation,
# Nearest to state: aggregated, pleated, visibly, dart, inequalities, lily, traverse, malfunctions,
# Nearest to of: semicircular, corsica, rodham, friar, rediscovered, impeach, aquatic, shy,
# Nearest to a: automakers, unnoticed, motherhood, phagocytosis, veterinarians, mwi, childbirth, alhazen,
# Nearest to their: grammar, conger, vein, racial, clarinets, polarized, visigoths, townsfolk,
# Nearest to or: heinrich, clausius, carmack, auf, benches, earthquakes, depends, xk,
# Average loss at step 2000: 4.379265
# Average loss at step 4000: 3.868339
# Average loss at step 6000: 3.789072
# Average loss at step 8000: 3.688340
# Average loss at step 10000: 3.617479
# Nearest to time: maclaurin, knights, flo, adamic, cultivation, argumentation, prophesied, anglican,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to has: had, is, was, have, dev, energized, tolerant, claiming,
# Nearest to from: at, on, in, by, hispanics, dismemberment, interceptors, for,
# Nearest to into: pc, miscellaneous, during, pouring, vertebrate, uso, tatian, rotations,
# Nearest to states: spherical, prosecution, foibles, moonshine, impeachment, cheques, excelling, distinct,
# Nearest to nine: eight, seven, six, four, zero, five, three, two,
# Nearest to d: nearest, beset, dakota, doom, groundwater, hall, vestigial, carcass,
# Nearest to been: was, medal, superposition, had, preferably, beatboxing, discernible, unlicensed,
# Nearest to people: chew, consoles, cheaper, coltrane, maghrib, chromosome, tempering, quadra,
# Nearest to about: stiles, nucleation, soloists, translator, abnormally, prelog, telnet, proving,
# Nearest to state: ibelin, reason, traverse, somers, visibly, malfunctions, hopeless, timpani,
# Nearest to of: in, longevity, skies, rv, autonomously, semicircular, on, and,
# Nearest to a: the, kerguelen, this, conquistadores, sporting, galloway, allocating, alhazen,
# Nearest to their: his, its, the, arbitrage, midway, emb, landsat, her,
# Nearest to or: and, but, than, kokomo, s, largo, frisia, compendium,
# Average loss at step 12000: 3.607098
# Average loss at step 14000: 3.571561
# Average loss at step 16000: 3.411099
# Average loss at step 18000: 3.462381
# Average loss at step 20000: 3.541787
# Nearest to time: maclaurin, cultivation, kgb, knights, reviewing, hesychasm, predominate, day,
# Nearest to eight: six, nine, seven, five, four, three, zero, two,
# Nearest to has: had, is, was, have, dev, pervading, sikhs, coffey,
# Nearest to from: in, through, into, for, at, by, between, with,
# Nearest to into: from, pc, during, slap, reemergence, over, in, antonym,
# Nearest to states: prosecution, spherical, foibles, cheques, excelling, moonshine, klister, hutton,
# Nearest to nine: eight, six, seven, four, zero, five, three, two,
# Nearest to d: b, flyers, diana, vestigial, conveyor, nearest, pads, ubu,
# Nearest to been: was, be, is, by, had, were, announcing, beatboxing,
# Nearest to people: chew, quadra, coltrane, cheaper, consoles, worldcom, tempering, plunder,
# Nearest to about: stiles, zines, christadelphians, prelog, rapes, soloists, translator, shepherd,
# Nearest to state: ibelin, emulsifiers, wagon, timpani, hark, visibly, indictees, categorical,
# Nearest to of: for, semicircular, habitus, haggard, interludes, philosophie, superhuman, in,
# Nearest to a: this, the, bakersfield, marsupial, buddies, or, allocating, any,
# Nearest to their: his, its, the, her, some, any, emb, arbitrage,
# Nearest to or: and, than, but, largo, vowed, utopia, creations, a,
# Average loss at step 22000: 3.506081
# Average loss at step 24000: 3.490595
# Average loss at step 26000: 3.484534
# Average loss at step 28000: 3.480118
# Average loss at step 30000: 3.503818
# Nearest to time: knights, gala, kgb, farewell, maclaurin, monastics, helms, cultivation,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to has: had, have, is, was, pervading, dev, disarray, hardly,
# Nearest to from: into, through, in, between, for, by, under, against,
# Nearest to into: from, over, during, under, interludes, slap, antonym, reemergence,
# Nearest to states: foibles, moonshine, spherical, excelling, prosecution, hutton, cheques, klister,
# Nearest to nine: eight, six, seven, four, five, three, zero, two,
# Nearest to d: b, conveyor, vestigial, flyers, diana, ubu, abeda, october,
# Nearest to been: was, be, become, announcing, dimers, were, beatboxing, had,
# Nearest to people: chew, americans, quadra, students, jews, those, consoles, plunder,
# Nearest to about: vulgate, translator, nucleation, aix, previous, zines, marlowe, shepherd,
# Nearest to state: ibelin, bantam, reason, man, body, virtually, hark, categorical,
# Nearest to of: in, and, for, semicircular, unresponsive, haggard, from, including,
# Nearest to a: any, bakersfield, the, another, anesthetic, savings, instructions, marsupial,
# Nearest to their: its, his, the, her, some, any, these, your,
# Nearest to or: and, vowed, hula, pissarro, rowe, endosymbionts, than, bosniak,
# Average loss at step 32000: 3.501762
# Average loss at step 34000: 3.491648
# Average loss at step 36000: 3.451596
# Average loss at step 38000: 3.305017
# Average loss at step 40000: 3.430146
# Nearest to time: kgb, gala, filius, prophesied, enola, period, venice, year,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to has: had, have, was, is, began, disarray, inverting, dev,
# Nearest to from: into, through, in, between, of, dismemberment, bessel, under,
# Nearest to into: from, through, during, back, over, ionic, across, under,
# Nearest to states: kingdom, countries, nations, foibles, spherical, fractional, prosecution, excelling,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to d: b, UNK, flyers, inorganic, conveyor, confusingly, vestigial, bosniak,
# Nearest to been: become, be, was, begun, beatboxing, had, being, stockhausen,
# Nearest to people: jews, those, maghrib, students, chew, americans, persons, quays,
# Nearest to about: nucleation, translator, replete, marlowe, insider, zines, meanwhile, previous,
# Nearest to state: ibelin, city, council, taxation, virtually, confederate, government, hark,
# Nearest to of: peress, for, laertius, in, and, from, heath, semicircular,
# Nearest to a: the, another, any, allocating, tenet, marsupial, buddies, or,
# Nearest to their: its, his, her, any, your, the, some, them,
# Nearest to or: and, than, vowed, a, cues, grades, stanshall, supervisory,
# Average loss at step 42000: 3.438639
# Average loss at step 44000: 3.452770
# Average loss at step 46000: 3.447793
# Average loss at step 48000: 3.352410
# Average loss at step 50000: 3.383251
# Nearest to time: year, way, kgb, period, internationally, if, years, contest,
# Nearest to eight: nine, seven, six, four, five, three, zero, one,
# Nearest to has: had, have, was, is, since, jutta, ecotourism, retard,
# Nearest to from: through, into, in, within, at, hispanics, during, under,
# Nearest to into: from, through, across, back, during, window, slap, langston,
# Nearest to states: kingdom, nations, countries, foibles, coptic, prosecution, fractional, excelling,
# Nearest to nine: eight, seven, six, four, five, three, zero, one,
# Nearest to d: b, flyers, conveyor, inorganic, can, atop, stables, n,
# Nearest to been: become, begun, be, was, were, had, pitcairn, beatboxing,
# Nearest to people: jews, children, men, women, persons, characters, students, members,
# Nearest to about: insider, jaroslav, aix, lol, nucleation, replete, shocked, over,
# Nearest to state: ibelin, council, taxation, categorical, city, hark, traverse, government,
# Nearest to of: in, semicircular, and, traditional, including, algonquian, haggard, during,
# Nearest to a: another, the, any, allocating, bakersfield, instructions, hypnotized, unnoticed,
# Nearest to their: its, his, the, her, your, some, any, them,
# Nearest to or: and, than, vowed, des, creations, glycolysis, hula, synodic,
# Average loss at step 52000: 3.438691
# Average loss at step 54000: 3.426597
# Average loss at step 56000: 3.438221
# Average loss at step 58000: 3.399796
# Average loss at step 60000: 3.394195
# Nearest to time: period, way, internationally, yevgeny, year, manner, kgb, thing,
# Nearest to eight: six, nine, four, seven, five, three, zero, two,
# Nearest to has: had, have, was, is, ecotourism, mistranslation, gathers, sherlock,
# Nearest to from: through, into, in, including, by, nihilism, between, hispanics,
# Nearest to into: through, from, across, back, along, between, slap, against,
# Nearest to states: kingdom, countries, nations, foibles, forces, fractional, coptic, beneficiary,
# Nearest to nine: eight, six, seven, four, five, three, zero, one,
# Nearest to d: b, stables, inorganic, atop, r, pectoral, c, m,
# Nearest to been: become, be, begun, was, had, were, pitcairn, stockhausen,
# Nearest to people: jews, men, women, persons, students, those, plunder, americans,
# Nearest to about: over, replete, aix, translator, nucleation, shocked, insider, lol,
# Nearest to state: ibelin, council, city, categorical, government, taxation, hark, facilitates,
# Nearest to of: in, for, like, include, same, frick, dome, peress,
# Nearest to a: the, any, another, every, wettest, bakersfield, fits, historiography,
# Nearest to their: its, his, her, the, your, some, our, several,
# Nearest to or: and, than, but, baptisms, any, from, glycolysis, jargon,
# Average loss at step 62000: 3.240513
# Average loss at step 64000: 3.255547
# Average loss at step 66000: 3.401482
# Average loss at step 68000: 3.395285
# Average loss at step 70000: 3.357423
# Nearest to time: period, year, thing, kgb, internationally, manner, way, degree,
# Nearest to eight: nine, six, seven, four, five, zero, three, two,
# Nearest to has: had, have, was, is, since, pervading, although, yerushalmi,
# Nearest to from: through, into, towards, hispanics, in, by, within, between,
# Nearest to into: through, from, in, depicting, across, back, collects, deneb,
# Nearest to states: kingdom, nations, countries, beneficiary, fractional, foibles, coptic, excelling,
# Nearest to nine: eight, six, seven, four, five, zero, three, one,
# Nearest to d: b, pectoral, stables, h, inorganic, conveyor, panther, flyers,
# Nearest to been: become, be, begun, was, pitcairn, were, stockhausen, already,
# Nearest to people: women, men, persons, jews, students, americans, members, children,
# Nearest to about: over, aix, replete, lol, translator, nucleation, insider, median,
# Nearest to state: ibelin, city, categorical, government, council, society, hark, traverse,
# Nearest to of: including, include, in, kipper, same, ethnological, although, for,
# Nearest to a: the, another, any, bakersfield, allocating, electronvolt, marsupial, unnoticed,
# Nearest to their: its, his, her, the, your, some, these, themselves,
# Nearest to or: and, than, but, each, overuse, any, stroustrup, like,
# Average loss at step 72000: 3.372750
# Average loss at step 74000: 3.343336
# Average loss at step 76000: 3.318398
# Average loss at step 78000: 3.352957
# Average loss at step 80000: 3.376446
# Nearest to time: kgb, thing, year, period, manner, degree, years, hengest,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to has: had, have, is, was, since, although, having, pervading,
# Nearest to from: through, into, towards, in, within, including, after, across,
# Nearest to into: through, from, across, over, in, back, between, with,
# Nearest to states: kingdom, nations, countries, beneficiary, fractional, forces, coptic, excelling,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to d: b, h, vestigial, nordisk, m, stables, atop, acr,
# Nearest to been: become, be, begun, was, were, florin, pitcairn, had,
# Nearest to people: women, men, jews, students, persons, children, americans, members,
# Nearest to about: replete, over, lol, aix, nucleation, median, translator, shocked,
# Nearest to state: city, categorical, government, council, taxation, ibelin, states, hark,
# Nearest to of: in, including, semicircular, for, polyphyletic, grammaticus, wooded, despite,
# Nearest to a: another, the, bakersfield, marsupial, every, harappan, allocating, saddam,
# Nearest to their: its, his, her, your, themselves, our, the, several,
# Nearest to or: and, than, while, schellenberg, headland, des, but, ore,
# Average loss at step 82000: 3.409913
# Average loss at step 84000: 3.407679
# Average loss at step 86000: 3.389410
# Average loss at step 88000: 3.352346
# Average loss at step 90000: 3.366096
# Nearest to time: kgb, year, manner, period, if, thing, radiometric, expenditure,
# Nearest to eight: seven, six, five, nine, four, three, zero, two,
# Nearest to has: had, have, is, having, was, since, although, makes,
# Nearest to from: through, into, across, between, towards, within, during, halide,
# Nearest to into: through, from, between, across, back, over, using, interludes,
# Nearest to states: kingdom, nations, countries, state, fractional, beneficiary, forces, tariq,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to d: b, atop, k, eddy, sceptre, vladimir, nordisk, lothal,
# Nearest to been: become, be, was, begun, already, stockhausen, were, being,
# Nearest to people: jews, women, students, men, members, americans, persons, actors,
# Nearest to about: over, nucleation, aix, translator, shocked, lol, replete, teleplay,
# Nearest to state: city, categorical, government, states, council, taxation, area, slices,
# Nearest to of: semicircular, including, for, and, iterations, in, include, although,
# Nearest to a: the, any, another, enough, unnoticed, every, allocating, tenet,
# Nearest to their: its, his, her, our, your, themselves, whose, these,
# Nearest to or: and, than, hula, des, listens, ozark, without, including,
# Average loss at step 92000: 3.396500
# Average loss at step 94000: 3.253585
# Average loss at step 96000: 3.360833
# Average loss at step 98000: 3.244125
# Average loss at step 100000: 3.359775
# Nearest to time: manner, period, thing, year, confectionery, kgb, expenditure, reason,
# Nearest to eight: nine, seven, six, four, five, three, zero, two,
# Nearest to has: had, have, is, was, since, having, makes, although,
# Nearest to from: into, through, in, between, across, acorn, within, during,
# Nearest to into: through, from, in, within, back, across, interludes, supercharger,
# Nearest to states: kingdom, nations, countries, beneficiary, fractional, forces, state, us,
# Nearest to nine: eight, seven, six, four, five, three, zero, one,
# Nearest to d: b, k, acr, abe, diana, grenville, webcam, c,
# Nearest to been: become, be, already, begun, was, were, stockhausen, florin,
# Nearest to people: jews, students, persons, women, children, men, americans, individuals,
# Nearest to about: over, aix, on, shocked, lol, teleplay, replete, nucleation,
# Nearest to state: city, government, categorical, piazzi, lincoln, taxation, states, council,
# Nearest to of: including, in, frick, dwindling, during, breakdance, from, and,
# Nearest to a: another, any, the, bakersfield, allocating, tenet, instructions, unnoticed,
# Nearest to their: its, his, her, your, the, our, these, several,
# Nearest to or: and, than, riddled, any, vowed, hula, inspires, while,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
